# %%
import requests

url = "https://tokapi-mobile-version.p.rapidapi.com/v1/category"

querystring = {"count":"10","region":"US"}

headers = {
	"X-RapidAPI-Key": "c24befee85mshd9daedc7f8f67fdp10ae0djsn6a02ee356eb8",
	"X-RapidAPI-Host": "tokapi-mobile-version.p.rapidapi.com"
}

response = requests.get(url, headers=headers, params=querystring)

print(response.json())
# Out:
# {'category_list': [{'aweme_list': [{'anchors': None, 'aweme_id': '7290745115516390699', 'banners': None, 'behind_the_song_music_ids': None, 'behind_the_song_video_music_ids': None, 'branded_content_accounts': None, 'cha_list': None, 'challenge_position': None, 'commerce_config_data': None, 'content_desc_extra': None, 'cover_labels': None, 'create_time': 1697508891, 'desc': 'Compilation of funny dogs  🤣🐶  . . . #dogs #dogsoftiktok #longervideos ', 'geofencing': None, 'geofencing_regions': None, 'green_screen_materials': None, 'hybrid_label': None, 'image_infos': None, 'interaction_stickers': None, 'is_pgcshow': False, 'label_top_text': None, 'long_video': None, 'mask_infos': None, 'muf_comment_info_v2': None, 'nickname_position': None, 'operator_boost_info': None, 'origin_comment_ids': None, 'picked_users': None, 'position': None, 'products_info': None, 'question_list': None, 'reference_tts_voice_ids': None, 'reference_voice_filter_ids': None, 'search_highlight': None, 'status': {'allow_comment': True, 'allow_share': True, 'download_status': 0, 'is_delete': False}, 'text_extra': None, 'tts_voice_ids': None, 'uniqid_position': None, 'video': {'animated_cover': {'uri': 'tos-useast5-p-0068-tx/f5c2a15a7d1943f5a84d8edd0a9999c1_1697508893', 'url_list': ['https://p16-sign.tiktokcdn-us.com/obj/tos-useast5-p-0068-tx/f5c2a15a7d1943f5a84d8edd0a9999c1_1697508893?x-expires=1700002800&x-signature=pBPvrwc%2ByIqLMvi7X%2FSUIweS3uY%3D&s=CHALLENGE_AWEME&se=false&sh=&sc=dynamic_cover&l=2023111323123456B75ED0D00BC5131834', 'https://p19-sign.tiktokcdn-us.com/obj/tos-useast5-p-0068-tx/f5c2a15a7d1943f5a84d8edd0a9999c1_1697508893?x-expires=1700002800&x-signature=gsaBgebAxqAJXXgy2fj%2FRxBrUsE%3D&s=CHALLENGE_AWEME&se=false&sh=&sc=dynamic_cover&l=2023111323123456B75ED0D00BC5131834'], 'url_prefix': None}, 'big_thumbs': None, 'bit_rate': None, 'bit_rate_audio': None, 'cover': {'height': 720, 'uri': 'tos-useast5-p-0068-tx/oIOCFkflREzmVKAAZBywNghZytIoISbBpmhv7A', 'url_list': ['https://p19-sign.tiktokcdn-us.com/tos-useast5-p-0068-tx/oIOCFkflREzmVKAAZBywNghZytIoISbBpmhv7A~c5_300x400.jpeg?x-expires=1700002800&x-signature=FMlq9n%2F%2FaSgk5NCU4hkavnOauvQ%3D&s=CHALLENGE_AWEME&se=false&sh=&sc=cover&l=2023111323123456B75ED0D00BC5131834', 'https://p16-sign.tiktokcdn-us.com/tos-useast5-p-0068-tx/oIOCFkflREzmVKAAZBywNghZytIoISbBpmhv7A~c5_300x400.jpeg?x-expires=1700002800&x-signature=kS2NcTEgQyWDXkM48TN9gKRrfYg%3D&s=CHALLENGE_AWEME&se=false&sh=&sc=cover&l=2023111323123456B75ED0D00BC5131834'], 'url_prefix': None, 'width': 720}, 'dynamic_cover': {'height': 720, 'uri': 'tos-useast5-p-0068-tx/29d9359a5e6f40b28ada81605358a92b_1697508893', 'url_list': ['https://p16-sign.tiktokcdn-us.com/obj/tos-useast5-p-0068-tx/29d9359a5e6f40b28ada81605358a92b_1697508893?x-expires=1700002800&x-signature=BozlvQdvEAg4TY5SnUZi0fq6RiQ%3D&s=CHALLENGE_AWEME&se=false&sh=&sc=dynamic_cover&l=2023111323123456B75ED0D00BC5131834', 'https://p19-sign.tiktokcdn-us.com/obj/tos-useast5-p-0068-tx/29d9359a5e6f40b28ada81605358a92b_1697508893?x-expires=1700002800&x-signature=ymf4xCjPibtDOqU5YCvPyMeU8Ak%3D&s=CHALLENGE_AWEME&se=false&sh=&sc=dynamic_cover&l=2023111323123456B75ED0D00BC5131834'], 'url_prefix': None, 'width': 720}, 'height': 1024, 'tags': None, 'width': 576}, 'video_labels': None, 'video_text': None, 'voice_filter_ids': None}, {'anchors': None, 'aweme_id': '7260630155159457070', 'banners': None, 'behind_the_song_music_ids': None, 'behind_the_song_video_music_ids': None, 'branded_content_accounts': None, 'cha_list': None, 'challenge_position': None, 'commerce_config_data': None, 'content_desc_extra': None, 'cover_labels': None, 'create_time': 1690497208, 'desc': 'She let him off the hook 😳 part 1 #fyp #cops #girlcops #hbpd #girls #viral #police #girlpolice #longervideos ', 'geofencing': None, 'geofencing_regions': None, 'green_screen_materials': None, 'hybrid_label': None, 'image_infos': None, 'interaction_stickers': None, 'is_pgcshow': False, 'label_top_text': None, 'long_video': None, 'mask_infos': No ...

# %%
if response.status_code == 200: 
    print(response.json()) 
else: 
    print(f"Error: {response.status_code}")
    if response.text: 
        print(response.text)
# Out:
# {'category_list': [{'aweme_list': [{'anchors': None, 'aweme_id': '7290745115516390699', 'banners': None, 'behind_the_song_music_ids': None, 'behind_the_song_video_music_ids': None, 'branded_content_accounts': None, 'cha_list': None, 'challenge_position': None, 'commerce_config_data': None, 'content_desc_extra': None, 'cover_labels': None, 'create_time': 1697508891, 'desc': 'Compilation of funny dogs  🤣🐶  . . . #dogs #dogsoftiktok #longervideos ', 'geofencing': None, 'geofencing_regions': None, 'green_screen_materials': None, 'hybrid_label': None, 'image_infos': None, 'interaction_stickers': None, 'is_pgcshow': False, 'label_top_text': None, 'long_video': None, 'mask_infos': None, 'muf_comment_info_v2': None, 'nickname_position': None, 'operator_boost_info': None, 'origin_comment_ids': None, 'picked_users': None, 'position': None, 'products_info': None, 'question_list': None, 'reference_tts_voice_ids': None, 'reference_voice_filter_ids': None, 'search_highlight': None, 'status': {'allow_comment': True, 'allow_share': True, 'download_status': 0, 'is_delete': False}, 'text_extra': None, 'tts_voice_ids': None, 'uniqid_position': None, 'video': {'animated_cover': {'uri': 'tos-useast5-p-0068-tx/f5c2a15a7d1943f5a84d8edd0a9999c1_1697508893', 'url_list': ['https://p16-sign.tiktokcdn-us.com/obj/tos-useast5-p-0068-tx/f5c2a15a7d1943f5a84d8edd0a9999c1_1697508893?x-expires=1700002800&x-signature=pBPvrwc%2ByIqLMvi7X%2FSUIweS3uY%3D&s=CHALLENGE_AWEME&se=false&sh=&sc=dynamic_cover&l=2023111323123456B75ED0D00BC5131834', 'https://p19-sign.tiktokcdn-us.com/obj/tos-useast5-p-0068-tx/f5c2a15a7d1943f5a84d8edd0a9999c1_1697508893?x-expires=1700002800&x-signature=gsaBgebAxqAJXXgy2fj%2FRxBrUsE%3D&s=CHALLENGE_AWEME&se=false&sh=&sc=dynamic_cover&l=2023111323123456B75ED0D00BC5131834'], 'url_prefix': None}, 'big_thumbs': None, 'bit_rate': None, 'bit_rate_audio': None, 'cover': {'height': 720, 'uri': 'tos-useast5-p-0068-tx/oIOCFkflREzmVKAAZBywNghZytIoISbBpmhv7A', 'url_list': ['https://p19-sign.tiktokcdn-us.com/tos-useast5-p-0068-tx/oIOCFkflREzmVKAAZBywNghZytIoISbBpmhv7A~c5_300x400.jpeg?x-expires=1700002800&x-signature=FMlq9n%2F%2FaSgk5NCU4hkavnOauvQ%3D&s=CHALLENGE_AWEME&se=false&sh=&sc=cover&l=2023111323123456B75ED0D00BC5131834', 'https://p16-sign.tiktokcdn-us.com/tos-useast5-p-0068-tx/oIOCFkflREzmVKAAZBywNghZytIoISbBpmhv7A~c5_300x400.jpeg?x-expires=1700002800&x-signature=kS2NcTEgQyWDXkM48TN9gKRrfYg%3D&s=CHALLENGE_AWEME&se=false&sh=&sc=cover&l=2023111323123456B75ED0D00BC5131834'], 'url_prefix': None, 'width': 720}, 'dynamic_cover': {'height': 720, 'uri': 'tos-useast5-p-0068-tx/29d9359a5e6f40b28ada81605358a92b_1697508893', 'url_list': ['https://p16-sign.tiktokcdn-us.com/obj/tos-useast5-p-0068-tx/29d9359a5e6f40b28ada81605358a92b_1697508893?x-expires=1700002800&x-signature=BozlvQdvEAg4TY5SnUZi0fq6RiQ%3D&s=CHALLENGE_AWEME&se=false&sh=&sc=dynamic_cover&l=2023111323123456B75ED0D00BC5131834', 'https://p19-sign.tiktokcdn-us.com/obj/tos-useast5-p-0068-tx/29d9359a5e6f40b28ada81605358a92b_1697508893?x-expires=1700002800&x-signature=ymf4xCjPibtDOqU5YCvPyMeU8Ak%3D&s=CHALLENGE_AWEME&se=false&sh=&sc=dynamic_cover&l=2023111323123456B75ED0D00BC5131834'], 'url_prefix': None, 'width': 720}, 'height': 1024, 'tags': None, 'width': 576}, 'video_labels': None, 'video_text': None, 'voice_filter_ids': None}, {'anchors': None, 'aweme_id': '7260630155159457070', 'banners': None, 'behind_the_song_music_ids': None, 'behind_the_song_video_music_ids': None, 'branded_content_accounts': None, 'cha_list': None, 'challenge_position': None, 'commerce_config_data': None, 'content_desc_extra': None, 'cover_labels': None, 'create_time': 1690497208, 'desc': 'She let him off the hook 😳 part 1 #fyp #cops #girlcops #hbpd #girls #viral #police #girlpolice #longervideos ', 'geofencing': None, 'geofencing_regions': None, 'green_screen_materials': None, 'hybrid_label': None, 'image_infos': None, 'interaction_stickers': None, 'is_pgcshow': False, 'label_top_text': None, 'long_video': None, 'mask_infos': No ...
